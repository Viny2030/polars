# %% [markdown]
# <a href="https://colab.research.google.com/github/VINY1958/polars/blob/main/bds_polars_003_00.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p align="center">
# <img src="https://github.com/cristiandarioortegayubro/BDS/blob/main/images/Logo%20Pandas.png?raw=true">
# </p>

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <p align="justify">
# El script <code>import warnings</code> seguido de <code>warnings.filterwarnings('ignore')</code> se utiliza para importar el módulo de advertencias en Python y configurar el entorno para que ignore todas las advertencias que puedan generarse durante la ejecución del código. Esto evita que se muestren mensajes de advertencia al usuario, lo que puede ser útil para reducir el ruido en la salida del programa, aunque también puede ocultar advertencias importantes que podrían señalar problemas potenciales en el código.

# %% [markdown]
#  # **<font color="#07a8ed">Cargando datos en Pandas, formatos y archivo de datos 🐼 </font>**

# %% [markdown]
# <p align="justify">
# Leer datos y hacerlos accesibles, a veces denominado carga de datos, uno de los pasos del ETL: <ul><li>Extract</li><li>Transform</li><li>Load</li></ul></p> <p align="justify">
# es el primer paso necesario para todo lo que queremos hacer. El término análisis también se usa a veces para describir la carga de datos de texto y su interpretación como tablas y diferentes tipos de datos. Ahora vamos a desarrollar la entrada y salida de datos usando <code>Pandas</code>, aunque existen numerosas herramientas en otras bibliotecas para hacer lo mismo.
# </p>

# %% [markdown]
# <p align="justify"> 👀 Por convención, así se importa <code>Pandas</code>:  </p>

# %%
import numpy as np
import pandas as pd

# %%
# !pip install polars
# Out:
# Requirement already satisfied: polars in /usr/local/lib/python3.10/dist-packages (1.7.1)

# %%
import polars as pl

# %% [markdown]
#  # **<font color="#07a8ed">Leer y escribir datos en formato de texto</font>**

# %% [markdown]
# <p align="justify">
# <code>Pandas</code> presenta una serie de funciones para leer datos tabulares como un objeto <code>DataFrame</code>.</p>

# %% [markdown]
# <p align="justify"> 👀 Esas funciones son:
# <ul>
# <li><code>read_csv()</code> datos delimitados desde archivo CSV, una dirección URL u objeto similar a un archivo</li>
# <li><code>read_fwf()</code> datos en formato de columna de ancho fijo sin delimitadores</li>
# <li><code>read_excel()</code> datos tabulares de un archivo Excel XLS o XLSX</li>
# <li><code>read_hdf()</code> archivos HDF5 escritos por <code>Pandas</code></li>
# <li><code>read_html()</code> todas las tablas que se encuentran en el documento HTML</li>
# <li><code>read_json()</code> datos de una cadena, archivo, URL u objeto similar a un archivo JSON (JavaScript Object Notation)</li>
# <li><code>read_feather()</code> formato de archivo binario Feather</li>
# <li><code>read_orc()</code> formato de archivo binario Apache ORC</li>
# <li><code>read_parquet()</code> formato de archivo binario Apache Parquet</li>
# <li><code>read_pickle()</code> objeto almacenado por <code>Pandas</code> usando el formato pickle de <code>Python</code></li>
# <li><code>read_sas()</code> conjunto de datos SAS almacenado en formato de almacenamiento del sistema SAS</li>
# <li><code>read_spss()</code> archivo de datos creado por SPSS</li>
# <li><code>read_sql()</code> resultados de una consulta SQL (usando SQLAlchemy)</li>
# <li><code>read_sql_table()</code> tabla SQL completa (usando SQLAlchemy); equivalente a una consulta que selecciona todo</li>
# <li><code>read_stata()</code> conjunto de datos del formato de archivo Stata</li>
# <li><code>read_xml()</code> tabla de datos de un archivo XML</li>
# </ul>
# </p>

# %% [markdown]
#  ## **<font color="#07a8ed">Lectura de archivos en partes</font>**

# %% [markdown]
# <p align="justify">
# Al procesar archivos muy grandes o descubrir el conjunto correcto de argumentos para procesar correctamente un archivo grande, <code>Pandas</code> permite leer solo una pequeña parte de un archivo o iterar a través de partes más pequeñas del archivo.</p>

# %%
datos="https://raw.githubusercontent.com/cristiandarioortegayubro/BDS/main/datasets/beneficios-otorgados-colaborativa-202210.xlsx-Dataset.csv"

# %%
subsidios = pl.read_csv(datos)
subsidios.head(10)
# Out:
# shape: (10, 14)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ beneficio ┆ beneficia ┆ beneficia ┆ proyecto_ ┆ … ┆ localidad ┆ resolucio ┆ anr_abona ┆ subsidio │
# │ _tipo     ┆ rio_razon ┆ rio_cuit  ┆ nombre    ┆   ┆ _id       ┆ n         ┆ do        ┆ _tasa_cr │
# │ ---       ┆ _social   ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ edito    │
# │ str       ┆ ---       ┆ i64       ┆ str       ┆   ┆ i64       ┆ str       ┆ i64       ┆ ---      │
# │           ┆ str       ┆           ┆           ┆   ┆           ┆           ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ Bonificac ┆ Esg Dilec ┆ 307083345 ┆ Sistema   ┆ … ┆ 820842700 ┆ RESOL-202 ┆ null      ┆ 4008128  │
# │ ión de    ┆ SA        ┆ 84        ┆ multiplat ┆   ┆ 00        ┆ 1-407-APN ┆           ┆          │
# │ tasa cred ┆           ┆           ┆ aforma de ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆           ┆           ┆ lec…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Esg Dilec ┆ 307083345 ┆ Sistema   ┆ … ┆ 820842700 ┆ RESOL-202 ┆ 4954725   ┆ null     │
# │           ┆ SA        ┆ 84        ┆ multiplat ┆   ┆ 00        ┆ 1-407-APN ┆           ┆          │
# │           ┆           ┆           ┆ aforma de ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆           ┆           ┆ lec…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Laborator ┆ 306380641 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ 4482165   ┆ null     │
# │           ┆ io        ┆ 26        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │           ┆ Biológico ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆ Tandil S… ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ Bonificac ┆ Laborator ┆ 306380641 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ null      ┆ 720530   │
# │ ión de    ┆ io        ┆ 26        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │ tasa cred ┆ Biológico ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆ Tandil S… ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ Bonificac ┆ Redimec   ┆ 336297839 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ null      ┆ 737628   │
# │ ión de    ┆ SRL       ┆ 09        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │ tasa cred ┆           ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆           ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Redimec   ┆ 336297839 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ 8313999   ┆ null     │
# │           ┆ SRL       ┆ 09        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │           ┆           ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆           ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Itecnis   ┆ 307093922 ┆ “Sistema  ┆ … ┆ 820842700 ┆ RESOL-202 ┆ 4460000   ┆ null     │
# │           ┆ SRL       ┆ 43        ┆ de Certif ┆   ┆ 00        ┆ 1-359-APN ┆           ┆          │
# │           ┆           ┆           ┆ icación   ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆           ┆           ┆ de D…     ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ Bonificac ┆ Terragene ┆ 307095859 ┆ “Sistema  ┆ … ┆ 820842700 ┆ RESOL-202 ┆ null      ┆ 3853802  │
# │ ión de    ┆ SA        ┆ 39        ┆ de Certif ┆   ┆ 00        ┆ 1-359-APN ┆           ┆          │
# │ tasa cred ┆           ┆           ┆ icación   ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆           ┆           ┆ de D…     ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Terragene ┆ 307095859 ┆ “Sistema  ┆ … ┆ 820842700 ┆ RESOL-202 ┆ 6050000   ┆ null     │
# │           ┆ SA        ┆ 39        ┆ de Certif ┆   ┆ 00        ┆ 1-359-APN ┆           ┆          │
# │           ┆           ┆           ┆ icación   ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆           ┆           ┆ de D…     ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Colven SA ┆ 305603124 ┆ Sistema   ┆ … ┆ 820490700 ┆ RESOL-202 ┆ 600000    ┆ null     │
# │           ┆           ┆ 11        ┆ de        ┆   ┆ 00        ┆ 1-412-APN ┆           ┆          │
# │           ┆           ┆           ┆ Control y ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆           ┆           ┆ Transmisi ┆   ┆           ┆ #MD…      ┆           ┆          │
# │           ┆           ┆           ┆ …         ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
print(subsidios)
# Out:
# shape: (62, 14)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ beneficio ┆ beneficia ┆ beneficia ┆ proyecto_ ┆ … ┆ localidad ┆ resolucio ┆ anr_abona ┆ subsidio │
# │ _tipo     ┆ rio_razon ┆ rio_cuit  ┆ nombre    ┆   ┆ _id       ┆ n         ┆ do        ┆ _tasa_cr │
# │ ---       ┆ _social   ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ edito    │
# │ str       ┆ ---       ┆ i64       ┆ str       ┆   ┆ i64       ┆ str       ┆ i64       ┆ ---      │
# │           ┆ str       ┆           ┆           ┆   ┆           ┆           ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ Bonificac ┆ Esg Dilec ┆ 307083345 ┆ Sistema   ┆ … ┆ 820842700 ┆ RESOL-202 ┆ null      ┆ 4008128  │
# │ ión de    ┆ SA        ┆ 84        ┆ multiplat ┆   ┆ 00        ┆ 1-407-APN ┆           ┆          │
# │ tasa cred ┆           ┆           ┆ aforma de ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆           ┆           ┆ lec…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Esg Dilec ┆ 307083345 ┆ Sistema   ┆ … ┆ 820842700 ┆ RESOL-202 ┆ 4954725   ┆ null     │
# │           ┆ SA        ┆ 84        ┆ multiplat ┆   ┆ 00        ┆ 1-407-APN ┆           ┆          │
# │           ┆           ┆           ┆ aforma de ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆           ┆           ┆ lec…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Laborator ┆ 306380641 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ 4482165   ┆ null     │
# │           ┆ io        ┆ 26        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │           ┆ Biológico ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆ Tandil S… ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ Bonificac ┆ Laborator ┆ 306380641 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ null      ┆ 720530   │
# │ ión de    ┆ io        ┆ 26        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │ tasa cred ┆ Biológico ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆ Tandil S… ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ Bonificac ┆ Redimec   ┆ 336297839 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ null      ┆ 737628   │
# │ ión de    ┆ SRL       ┆ 09        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │ tasa cred ┆           ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆           ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ Bonificac ┆ Biogénesi ┆ 306533998 ┆ Desarroll ┆ … ┆ 625201000 ┆ RESOL-202 ┆ null      ┆ 7137021  │
# │ ión de    ┆ s Bagó    ┆ 19        ┆ o de      ┆   ┆ 3         ┆ 1-1052-AP ┆           ┆          │
# │ tasa cred ┆ S.A.      ┆           ┆ cepas ext ┆   ┆           ┆ N-SIECYGC ┆           ┆          │
# │ itici…    ┆           ┆           ┆ ra-regi…  ┆   ┆           ┆ E#M…      ┆           ┆          │
# │ ANR       ┆ Servicio  ┆ 306883845 ┆ Desarroll ┆ … ┆ 200001000 ┆ RESOL-202 ┆ 9165481   ┆ null     │
# │           ┆ Nacional  ┆ 47        ┆ o de      ┆   ┆ 0         ┆ 1-1052-AP ┆           ┆          │
# │           ┆ De        ┆           ┆ cepas ext ┆   ┆           ┆ N-SIECYGC ┆           ┆          │
# │           ┆ Sanidad   ┆           ┆ ra-regi…  ┆   ┆           ┆ E#M…      ┆           ┆          │
# │           ┆ Y…        ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ANR       ┆ Ferretera ┆ 307072971 ┆ Relevamie ┆ … ┆ 141402200 ┆ RESOL-202 ┆ 860000    ┆ null     │
# │           ┆ General   ┆ 54        ┆ nto de    ┆   ┆ 00        ┆ 2-160-APN ┆           ┆          │
# │           ┆ Paz       ┆           ┆ depósitos ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆ S.R.L.    ┆           ┆ a tr…     ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ Bonificac ┆ Ferretera ┆ 307072971 ┆ Relevamie ┆ … ┆ 141402200 ┆ RESOL-202 ┆ null      ┆ 196123   │
# │ ión de    ┆ General   ┆ 54        ┆ nto de    ┆   ┆ 00        ┆ 2-160-APN ┆           ┆          │
# │ tasa cred ┆ Paz       ┆           ┆ depósitos ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆ S.R.L.    ┆           ┆ a tr…     ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Fundación ┆ 307101811 ┆ Relevamie ┆ … ┆ 140140100 ┆ RESOL-202 ┆ 4950000   ┆ null     │
# │           ┆ Emprendim ┆ 75        ┆ nto de    ┆   ┆ 00        ┆ 2-160-APN ┆           ┆          │
# │           ┆ ientos Y  ┆           ┆ depósitos ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆ De…       ┆           ┆ a tr…     ┆   ┆           ┆ #MD…      ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
subsidios
# Out:
# shape: (62, 14)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ beneficio ┆ beneficia ┆ beneficia ┆ proyecto_ ┆ … ┆ localidad ┆ resolucio ┆ anr_abona ┆ subsidio │
# │ _tipo     ┆ rio_razon ┆ rio_cuit  ┆ nombre    ┆   ┆ _id       ┆ n         ┆ do        ┆ _tasa_cr │
# │ ---       ┆ _social   ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ edito    │
# │ str       ┆ ---       ┆ i64       ┆ str       ┆   ┆ i64       ┆ str       ┆ i64       ┆ ---      │
# │           ┆ str       ┆           ┆           ┆   ┆           ┆           ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ Bonificac ┆ Esg Dilec ┆ 307083345 ┆ Sistema   ┆ … ┆ 820842700 ┆ RESOL-202 ┆ null      ┆ 4008128  │
# │ ión de    ┆ SA        ┆ 84        ┆ multiplat ┆   ┆ 00        ┆ 1-407-APN ┆           ┆          │
# │ tasa cred ┆           ┆           ┆ aforma de ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆           ┆           ┆ lec…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Esg Dilec ┆ 307083345 ┆ Sistema   ┆ … ┆ 820842700 ┆ RESOL-202 ┆ 4954725   ┆ null     │
# │           ┆ SA        ┆ 84        ┆ multiplat ┆   ┆ 00        ┆ 1-407-APN ┆           ┆          │
# │           ┆           ┆           ┆ aforma de ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆           ┆           ┆ lec…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Laborator ┆ 306380641 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ 4482165   ┆ null     │
# │           ┆ io        ┆ 26        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │           ┆ Biológico ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆ Tandil S… ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ Bonificac ┆ Laborator ┆ 306380641 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ null      ┆ 720530   │
# │ ión de    ┆ io        ┆ 26        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │ tasa cred ┆ Biológico ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆ Tandil S… ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ Bonificac ┆ Redimec   ┆ 336297839 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ null      ┆ 737628   │
# │ ión de    ┆ SRL       ┆ 09        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │ tasa cred ┆           ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆           ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ Bonificac ┆ Biogénesi ┆ 306533998 ┆ Desarroll ┆ … ┆ 625201000 ┆ RESOL-202 ┆ null      ┆ 7137021  │
# │ ión de    ┆ s Bagó    ┆ 19        ┆ o de      ┆   ┆ 3         ┆ 1-1052-AP ┆           ┆          │
# │ tasa cred ┆ S.A.      ┆           ┆ cepas ext ┆   ┆           ┆ N-SIECYGC ┆           ┆          │
# │ itici…    ┆           ┆           ┆ ra-regi…  ┆   ┆           ┆ E#M…      ┆           ┆          │
# │ ANR       ┆ Servicio  ┆ 306883845 ┆ Desarroll ┆ … ┆ 200001000 ┆ RESOL-202 ┆ 9165481   ┆ null     │
# │           ┆ Nacional  ┆ 47        ┆ o de      ┆   ┆ 0         ┆ 1-1052-AP ┆           ┆          │
# │           ┆ De        ┆           ┆ cepas ext ┆   ┆           ┆ N-SIECYGC ┆           ┆          │
# │           ┆ Sanidad   ┆           ┆ ra-regi…  ┆   ┆           ┆ E#M…      ┆           ┆          │
# │           ┆ Y…        ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ANR       ┆ Ferretera ┆ 307072971 ┆ Relevamie ┆ … ┆ 141402200 ┆ RESOL-202 ┆ 860000    ┆ null     │
# │           ┆ General   ┆ 54        ┆ nto de    ┆   ┆ 00        ┆ 2-160-APN ┆           ┆          │
# │           ┆ Paz       ┆           ┆ depósitos ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆ S.R.L.    ┆           ┆ a tr…     ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ Bonificac ┆ Ferretera ┆ 307072971 ┆ Relevamie ┆ … ┆ 141402200 ┆ RESOL-202 ┆ null      ┆ 196123   │
# │ ión de    ┆ General   ┆ 54        ┆ nto de    ┆   ┆ 00        ┆ 2-160-APN ┆           ┆          │
# │ tasa cred ┆ Paz       ┆           ┆ depósitos ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆ S.R.L.    ┆           ┆ a tr…     ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Fundación ┆ 307101811 ┆ Relevamie ┆ … ┆ 140140100 ┆ RESOL-202 ┆ 4950000   ┆ null     │
# │           ┆ Emprendim ┆ 75        ┆ nto de    ┆   ┆ 00        ┆ 2-160-APN ┆           ┆          │
# │           ┆ ientos Y  ┆           ┆ depósitos ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆ De…       ┆           ┆ a tr…     ┆   ┆           ┆ #MD…      ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
subsidios_pl = pl.read_csv(datos)
subsidios_pl.head(10)
# Out:
# shape: (10, 14)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ beneficio ┆ beneficia ┆ beneficia ┆ proyecto_ ┆ … ┆ localidad ┆ resolucio ┆ anr_abona ┆ subsidio │
# │ _tipo     ┆ rio_razon ┆ rio_cuit  ┆ nombre    ┆   ┆ _id       ┆ n         ┆ do        ┆ _tasa_cr │
# │ ---       ┆ _social   ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ edito    │
# │ str       ┆ ---       ┆ i64       ┆ str       ┆   ┆ i64       ┆ str       ┆ i64       ┆ ---      │
# │           ┆ str       ┆           ┆           ┆   ┆           ┆           ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ Bonificac ┆ Esg Dilec ┆ 307083345 ┆ Sistema   ┆ … ┆ 820842700 ┆ RESOL-202 ┆ null      ┆ 4008128  │
# │ ión de    ┆ SA        ┆ 84        ┆ multiplat ┆   ┆ 00        ┆ 1-407-APN ┆           ┆          │
# │ tasa cred ┆           ┆           ┆ aforma de ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆           ┆           ┆ lec…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Esg Dilec ┆ 307083345 ┆ Sistema   ┆ … ┆ 820842700 ┆ RESOL-202 ┆ 4954725   ┆ null     │
# │           ┆ SA        ┆ 84        ┆ multiplat ┆   ┆ 00        ┆ 1-407-APN ┆           ┆          │
# │           ┆           ┆           ┆ aforma de ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆           ┆           ┆ lec…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Laborator ┆ 306380641 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ 4482165   ┆ null     │
# │           ┆ io        ┆ 26        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │           ┆ Biológico ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆ Tandil S… ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ Bonificac ┆ Laborator ┆ 306380641 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ null      ┆ 720530   │
# │ ión de    ┆ io        ┆ 26        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │ tasa cred ┆ Biológico ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆ Tandil S… ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ Bonificac ┆ Redimec   ┆ 336297839 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ null      ┆ 737628   │
# │ ión de    ┆ SRL       ┆ 09        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │ tasa cred ┆           ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆           ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Redimec   ┆ 336297839 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ 8313999   ┆ null     │
# │           ┆ SRL       ┆ 09        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │           ┆           ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆           ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Itecnis   ┆ 307093922 ┆ “Sistema  ┆ … ┆ 820842700 ┆ RESOL-202 ┆ 4460000   ┆ null     │
# │           ┆ SRL       ┆ 43        ┆ de Certif ┆   ┆ 00        ┆ 1-359-APN ┆           ┆          │
# │           ┆           ┆           ┆ icación   ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆           ┆           ┆ de D…     ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ Bonificac ┆ Terragene ┆ 307095859 ┆ “Sistema  ┆ … ┆ 820842700 ┆ RESOL-202 ┆ null      ┆ 3853802  │
# │ ión de    ┆ SA        ┆ 39        ┆ de Certif ┆   ┆ 00        ┆ 1-359-APN ┆           ┆          │
# │ tasa cred ┆           ┆           ┆ icación   ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆           ┆           ┆ de D…     ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Terragene ┆ 307095859 ┆ “Sistema  ┆ … ┆ 820842700 ┆ RESOL-202 ┆ 6050000   ┆ null     │
# │           ┆ SA        ┆ 39        ┆ de Certif ┆   ┆ 00        ┆ 1-359-APN ┆           ┆          │
# │           ┆           ┆           ┆ icación   ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆           ┆           ┆ de D…     ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Colven SA ┆ 305603124 ┆ Sistema   ┆ … ┆ 820490700 ┆ RESOL-202 ┆ 600000    ┆ null     │
# │           ┆           ┆ 11        ┆ de        ┆   ┆ 00        ┆ 1-412-APN ┆           ┆          │
# │           ┆           ┆           ┆ Control y ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆           ┆           ┆ Transmisi ┆   ┆           ┆ #MD…      ┆           ┆          │
# │           ┆           ┆           ┆ …         ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %% [markdown]
# <p align="justify"> 👀 Los puntos suspensivos $...$ indican que se han omitido las filas en el medio del <code>DataFrame</code>. Se puede leer solo una pequeña cantidad de filas (evitando leer todo el archivo), con el parámetro <code>nrows</code> indicando en él, la cantidad de filas o índices que se quieren leer.
# </p>

# %%
pd.read_csv(datos, nrows=4)
# Out:
#                     beneficio_tipo         beneficiario_razon_social  \
# 0  Bonificación de tasa crediticia                      Esg Dilec SA
# 1                              ANR                      Esg Dilec SA
# 2                              ANR  Laboratorio Biológico Tandil SRL
# 3  Bonificación de tasa crediticia  Laboratorio Biológico Tandil SRL
#
#    beneficiario_cuit                                    proyecto_nombre  \
# 0        30708334584  Sistema multiplataforma de lectura, explotació...
# 1        30708334584  Sistema multiplataforma de lectura, explotació...
# 2        30638064126                Fabricación de Polarímetro nacional
# 3        30638064126                Fabricación de Polarímetro nacional
#
#    proyecto_id                                   proyecto_resumen  \
# 0            1  La provisión de una plataforma informática y d...
# 1            1  La provisión de una plataforma informática y d...
# 2            2  Industrialización del codesarrollo realizado e...
# 3            2  Industrialización del codesarrollo realizado e...
#
#          sector_edc provincia_nombre  provincia_id localidad_nombre  \
# 0     Industria 4.0         Santa Fe            82          Rosario
# 1     Industria 4.0         Santa Fe            82          Rosario
# 2  Biotecnología \n     Buenos Aires             6           Tandil
# 3  Biotecnología \n     Buenos Aires             6           Tandil
#
#    localidad_id                       resolucion  anr_abonado  \
# 0   82084270000  RESOL-2021-407-APN-SIECYGCE#MDP          NaN
# 1   82084270000  RESOL-2021-407-APN-SIECYGCE#MDP    4954725.0
# 2    6791050000  RESOL-2021-416-APN-SIECYGCE#MDP    4482165.0
# 3    6791050000  RESOL-2021-416-APN-SIECYGCE#MDP          NaN
#
#    subsidio_tasa_credito
# 0              4008128.0
# 1                    NaN
# 2                    NaN
# 3               720530.0

# %%
pl.read_csv(datos)
# Out:
# shape: (62, 14)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ beneficio ┆ beneficia ┆ beneficia ┆ proyecto_ ┆ … ┆ localidad ┆ resolucio ┆ anr_abona ┆ subsidio │
# │ _tipo     ┆ rio_razon ┆ rio_cuit  ┆ nombre    ┆   ┆ _id       ┆ n         ┆ do        ┆ _tasa_cr │
# │ ---       ┆ _social   ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ edito    │
# │ str       ┆ ---       ┆ i64       ┆ str       ┆   ┆ i64       ┆ str       ┆ i64       ┆ ---      │
# │           ┆ str       ┆           ┆           ┆   ┆           ┆           ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ Bonificac ┆ Esg Dilec ┆ 307083345 ┆ Sistema   ┆ … ┆ 820842700 ┆ RESOL-202 ┆ null      ┆ 4008128  │
# │ ión de    ┆ SA        ┆ 84        ┆ multiplat ┆   ┆ 00        ┆ 1-407-APN ┆           ┆          │
# │ tasa cred ┆           ┆           ┆ aforma de ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆           ┆           ┆ lec…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Esg Dilec ┆ 307083345 ┆ Sistema   ┆ … ┆ 820842700 ┆ RESOL-202 ┆ 4954725   ┆ null     │
# │           ┆ SA        ┆ 84        ┆ multiplat ┆   ┆ 00        ┆ 1-407-APN ┆           ┆          │
# │           ┆           ┆           ┆ aforma de ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆           ┆           ┆ lec…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Laborator ┆ 306380641 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ 4482165   ┆ null     │
# │           ┆ io        ┆ 26        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │           ┆ Biológico ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆ Tandil S… ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ Bonificac ┆ Laborator ┆ 306380641 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ null      ┆ 720530   │
# │ ión de    ┆ io        ┆ 26        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │ tasa cred ┆ Biológico ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆ Tandil S… ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ Bonificac ┆ Redimec   ┆ 336297839 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ null      ┆ 737628   │
# │ ión de    ┆ SRL       ┆ 09        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │ tasa cred ┆           ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆           ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ Bonificac ┆ Biogénesi ┆ 306533998 ┆ Desarroll ┆ … ┆ 625201000 ┆ RESOL-202 ┆ null      ┆ 7137021  │
# │ ión de    ┆ s Bagó    ┆ 19        ┆ o de      ┆   ┆ 3         ┆ 1-1052-AP ┆           ┆          │
# │ tasa cred ┆ S.A.      ┆           ┆ cepas ext ┆   ┆           ┆ N-SIECYGC ┆           ┆          │
# │ itici…    ┆           ┆           ┆ ra-regi…  ┆   ┆           ┆ E#M…      ┆           ┆          │
# │ ANR       ┆ Servicio  ┆ 306883845 ┆ Desarroll ┆ … ┆ 200001000 ┆ RESOL-202 ┆ 9165481   ┆ null     │
# │           ┆ Nacional  ┆ 47        ┆ o de      ┆   ┆ 0         ┆ 1-1052-AP ┆           ┆          │
# │           ┆ De        ┆           ┆ cepas ext ┆   ┆           ┆ N-SIECYGC ┆           ┆          │
# │           ┆ Sanidad   ┆           ┆ ra-regi…  ┆   ┆           ┆ E#M…      ┆           ┆          │
# │           ┆ Y…        ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ANR       ┆ Ferretera ┆ 307072971 ┆ Relevamie ┆ … ┆ 141402200 ┆ RESOL-202 ┆ 860000    ┆ null     │
# │           ┆ General   ┆ 54        ┆ nto de    ┆   ┆ 00        ┆ 2-160-APN ┆           ┆          │
# │           ┆ Paz       ┆           ┆ depósitos ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆ S.R.L.    ┆           ┆ a tr…     ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ Bonificac ┆ Ferretera ┆ 307072971 ┆ Relevamie ┆ … ┆ 141402200 ┆ RESOL-202 ┆ null      ┆ 196123   │
# │ ión de    ┆ General   ┆ 54        ┆ nto de    ┆   ┆ 00        ┆ 2-160-APN ┆           ┆          │
# │ tasa cred ┆ Paz       ┆           ┆ depósitos ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆ S.R.L.    ┆           ┆ a tr…     ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Fundación ┆ 307101811 ┆ Relevamie ┆ … ┆ 140140100 ┆ RESOL-202 ┆ 4950000   ┆ null     │
# │           ┆ Emprendim ┆ 75        ┆ nto de    ┆   ┆ 00        ┆ 2-160-APN ┆           ┆          │
# │           ┆ ientos Y  ┆           ┆ depósitos ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆ De…       ┆           ┆ a tr…     ┆   ┆           ┆ #MD…      ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
subsidios1 = pd.read_csv(datos, nrows=4)
subsidios1
# Out:
#                     beneficio_tipo         beneficiario_razon_social  \
# 0  Bonificación de tasa crediticia                      Esg Dilec SA
# 1                              ANR                      Esg Dilec SA
# 2                              ANR  Laboratorio Biológico Tandil SRL
# 3  Bonificación de tasa crediticia  Laboratorio Biológico Tandil SRL
#
#    beneficiario_cuit                                    proyecto_nombre  \
# 0        30708334584  Sistema multiplataforma de lectura, explotació...
# 1        30708334584  Sistema multiplataforma de lectura, explotació...
# 2        30638064126                Fabricación de Polarímetro nacional
# 3        30638064126                Fabricación de Polarímetro nacional
#
#    proyecto_id                                   proyecto_resumen  \
# 0            1  La provisión de una plataforma informática y d...
# 1            1  La provisión de una plataforma informática y d...
# 2            2  Industrialización del codesarrollo realizado e...
# 3            2  Industrialización del codesarrollo realizado e...
#
#          sector_edc provincia_nombre  provincia_id localidad_nombre  \
# 0     Industria 4.0         Santa Fe            82          Rosario
# 1     Industria 4.0         Santa Fe            82          Rosario
# 2  Biotecnología \n     Buenos Aires             6           Tandil
# 3  Biotecnología \n     Buenos Aires             6           Tandil
#
#    localidad_id                       resolucion  anr_abonado  \
# 0   82084270000  RESOL-2021-407-APN-SIECYGCE#MDP          NaN
# 1   82084270000  RESOL-2021-407-APN-SIECYGCE#MDP    4954725.0
# 2    6791050000  RESOL-2021-416-APN-SIECYGCE#MDP    4482165.0
# 3    6791050000  RESOL-2021-416-APN-SIECYGCE#MDP          NaN
#
#    subsidio_tasa_credito
# 0              4008128.0
# 1                    NaN
# 2                    NaN
# 3               720530.0

# %%
subsidios1_pl = pl.read_csv(datos)
subsidios1_pl.head(4)
# Out:
# shape: (4, 14)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ beneficio ┆ beneficia ┆ beneficia ┆ proyecto_ ┆ … ┆ localidad ┆ resolucio ┆ anr_abona ┆ subsidio │
# │ _tipo     ┆ rio_razon ┆ rio_cuit  ┆ nombre    ┆   ┆ _id       ┆ n         ┆ do        ┆ _tasa_cr │
# │ ---       ┆ _social   ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ edito    │
# │ str       ┆ ---       ┆ i64       ┆ str       ┆   ┆ i64       ┆ str       ┆ i64       ┆ ---      │
# │           ┆ str       ┆           ┆           ┆   ┆           ┆           ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ Bonificac ┆ Esg Dilec ┆ 307083345 ┆ Sistema   ┆ … ┆ 820842700 ┆ RESOL-202 ┆ null      ┆ 4008128  │
# │ ión de    ┆ SA        ┆ 84        ┆ multiplat ┆   ┆ 00        ┆ 1-407-APN ┆           ┆          │
# │ tasa cred ┆           ┆           ┆ aforma de ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆           ┆           ┆ lec…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Esg Dilec ┆ 307083345 ┆ Sistema   ┆ … ┆ 820842700 ┆ RESOL-202 ┆ 4954725   ┆ null     │
# │           ┆ SA        ┆ 84        ┆ multiplat ┆   ┆ 00        ┆ 1-407-APN ┆           ┆          │
# │           ┆           ┆           ┆ aforma de ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆           ┆           ┆ lec…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Laborator ┆ 306380641 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ 4482165   ┆ null     │
# │           ┆ io        ┆ 26        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │           ┆ Biológico ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆ Tandil S… ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ Bonificac ┆ Laborator ┆ 306380641 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ null      ┆ 720530   │
# │ ión de    ┆ io        ┆ 26        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │ tasa cred ┆ Biológico ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆ Tandil S… ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
subsidios.shape ## filas y columnas del dataset
# Out:
# (62, 14)

# %%
subsidios_pl
# Out:
# shape: (62, 14)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ beneficio ┆ beneficia ┆ beneficia ┆ proyecto_ ┆ … ┆ localidad ┆ resolucio ┆ anr_abona ┆ subsidio │
# │ _tipo     ┆ rio_razon ┆ rio_cuit  ┆ nombre    ┆   ┆ _id       ┆ n         ┆ do        ┆ _tasa_cr │
# │ ---       ┆ _social   ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ edito    │
# │ str       ┆ ---       ┆ i64       ┆ str       ┆   ┆ i64       ┆ str       ┆ i64       ┆ ---      │
# │           ┆ str       ┆           ┆           ┆   ┆           ┆           ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ Bonificac ┆ Esg Dilec ┆ 307083345 ┆ Sistema   ┆ … ┆ 820842700 ┆ RESOL-202 ┆ null      ┆ 4008128  │
# │ ión de    ┆ SA        ┆ 84        ┆ multiplat ┆   ┆ 00        ┆ 1-407-APN ┆           ┆          │
# │ tasa cred ┆           ┆           ┆ aforma de ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆           ┆           ┆ lec…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Esg Dilec ┆ 307083345 ┆ Sistema   ┆ … ┆ 820842700 ┆ RESOL-202 ┆ 4954725   ┆ null     │
# │           ┆ SA        ┆ 84        ┆ multiplat ┆   ┆ 00        ┆ 1-407-APN ┆           ┆          │
# │           ┆           ┆           ┆ aforma de ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆           ┆           ┆ lec…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Laborator ┆ 306380641 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ 4482165   ┆ null     │
# │           ┆ io        ┆ 26        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │           ┆ Biológico ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆ Tandil S… ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ Bonificac ┆ Laborator ┆ 306380641 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ null      ┆ 720530   │
# │ ión de    ┆ io        ┆ 26        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │ tasa cred ┆ Biológico ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆ Tandil S… ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ Bonificac ┆ Redimec   ┆ 336297839 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ null      ┆ 737628   │
# │ ión de    ┆ SRL       ┆ 09        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │ tasa cred ┆           ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆           ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ Bonificac ┆ Biogénesi ┆ 306533998 ┆ Desarroll ┆ … ┆ 625201000 ┆ RESOL-202 ┆ null      ┆ 7137021  │
# │ ión de    ┆ s Bagó    ┆ 19        ┆ o de      ┆   ┆ 3         ┆ 1-1052-AP ┆           ┆          │
# │ tasa cred ┆ S.A.      ┆           ┆ cepas ext ┆   ┆           ┆ N-SIECYGC ┆           ┆          │
# │ itici…    ┆           ┆           ┆ ra-regi…  ┆   ┆           ┆ E#M…      ┆           ┆          │
# │ ANR       ┆ Servicio  ┆ 306883845 ┆ Desarroll ┆ … ┆ 200001000 ┆ RESOL-202 ┆ 9165481   ┆ null     │
# │           ┆ Nacional  ┆ 47        ┆ o de      ┆   ┆ 0         ┆ 1-1052-AP ┆           ┆          │
# │           ┆ De        ┆           ┆ cepas ext ┆   ┆           ┆ N-SIECYGC ┆           ┆          │
# │           ┆ Sanidad   ┆           ┆ ra-regi…  ┆   ┆           ┆ E#M…      ┆           ┆          │
# │           ┆ Y…        ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ANR       ┆ Ferretera ┆ 307072971 ┆ Relevamie ┆ … ┆ 141402200 ┆ RESOL-202 ┆ 860000    ┆ null     │
# │           ┆ General   ┆ 54        ┆ nto de    ┆   ┆ 00        ┆ 2-160-APN ┆           ┆          │
# │           ┆ Paz       ┆           ┆ depósitos ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆ S.R.L.    ┆           ┆ a tr…     ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ Bonificac ┆ Ferretera ┆ 307072971 ┆ Relevamie ┆ … ┆ 141402200 ┆ RESOL-202 ┆ null      ┆ 196123   │
# │ ión de    ┆ General   ┆ 54        ┆ nto de    ┆   ┆ 00        ┆ 2-160-APN ┆           ┆          │
# │ tasa cred ┆ Paz       ┆           ┆ depósitos ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆ S.R.L.    ┆           ┆ a tr…     ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Fundación ┆ 307101811 ┆ Relevamie ┆ … ┆ 140140100 ┆ RESOL-202 ┆ 4950000   ┆ null     │
# │           ┆ Emprendim ┆ 75        ┆ nto de    ┆   ┆ 00        ┆ 2-160-APN ┆           ┆          │
# │           ┆ ientos Y  ┆           ┆ depósitos ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆ De…       ┆           ┆ a tr…     ┆   ┆           ┆ #MD…      ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
subsidios.columns  ## columnas del dataset
# Out:
# ['beneficio_tipo',
#  'beneficiario_razon_social',
#  'beneficiario_cuit',
#  'proyecto_nombre',
#  'proyecto_id',
#  'proyecto_resumen',
#  'sector_edc',
#  'provincia_nombre',
#  'provincia_id',
#  'localidad_nombre',
#  'localidad_id',
#  'resolucion',
#  'anr_abonado',
#  'subsidio_tasa_credito']

# %%
subsidios_pl.columns
# Out:
# ['beneficio_tipo',
#  'beneficiario_razon_social',
#  'beneficiario_cuit',
#  'proyecto_nombre',
#  'proyecto_id',
#  'proyecto_resumen',
#  'sector_edc',
#  'provincia_nombre',
#  'provincia_id',
#  'localidad_nombre',
#  'localidad_id',
#  'resolucion',
#  'anr_abonado',
#  'subsidio_tasa_credito']

# %%
subsidios.dtypes  ## listo tipos de datos
# Out:
# [String,
#  String,
#  Int64,
#  String,
#  Int64,
#  String,
#  String,
#  String,
#  Int64,
#  String,
#  Int64,
#  String,
#  Int64,
#  String]

# %%
subsidios_pl.dtypes
# Out:
# [String,
#  String,
#  Int64,
#  String,
#  Int64,
#  String,
#  String,
#  String,
#  Int64,
#  String,
#  Int64,
#  String,
#  Int64,
#  String]

# %%
subsidios_pl.shape
# Out:
# (62, 14)

# %%
subsidios_pl =subsidios_pl.cast

# %%
subsidios_pl
# Out:
# <bound method DataFrame.cast of shape: (62, 14)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ beneficio ┆ beneficia ┆ beneficia ┆ proyecto_ ┆ … ┆ localidad ┆ resolucio ┆ anr_abona ┆ subsidio │
# │ _tipo     ┆ rio_razon ┆ rio_cuit  ┆ nombre    ┆   ┆ _id       ┆ n         ┆ do        ┆ _tasa_cr │
# │ ---       ┆ _social   ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ edito    │
# │ str       ┆ ---       ┆ i64       ┆ str       ┆   ┆ i64       ┆ str       ┆ i64       ┆ ---      │
# │           ┆ str       ┆           ┆           ┆   ┆           ┆           ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ Bonificac ┆ Esg Dilec ┆ 307083345 ┆ Sistema   ┆ … ┆ 820842700 ┆ RESOL-202 ┆ null      ┆ 4008128  │
# │ ión de    ┆ SA        ┆ 84        ┆ multiplat ┆   ┆ 00        ┆ 1-407-APN ┆           ┆          │
# │ tasa cred ┆           ┆           ┆ aforma de ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆           ┆           ┆ lec…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Esg Dilec ┆ 307083345 ┆ Sistema   ┆ … ┆ 820842700 ┆ RESOL-202 ┆ 4954725   ┆ null     │
# │           ┆ SA        ┆ 84        ┆ multiplat ┆   ┆ 00        ┆ 1-407-APN ┆           ┆          │
# │           ┆           ┆           ┆ aforma de ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆           ┆           ┆ lec…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Laborator ┆ 306380641 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ 4482165   ┆ null     │
# │           ┆ io        ┆ 26        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │           ┆ Biológico ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆ Tandil S… ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ Bonificac ┆ Laborator ┆ 306380641 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ null      ┆ 720530   │
# │ ión de    ┆ io        ┆ 26        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │ tasa cred ┆ Biológico ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆ Tandil S… ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ Bonificac ┆ Redimec   ┆ 336297839 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ null      ┆ 737628   │
# │ ión de    ┆ SRL       ┆ 09        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │ tasa cred ┆           ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆           ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ Bonificac ┆ Biogénesi ┆ 306533998 ┆ Desarroll ┆ … ┆ 625201000 ┆ RESOL-202 ┆ null      ┆ 7137021  │
# │ ión de    ┆ s Bagó    ┆ 19        ┆ o de      ┆   ┆ 3         ┆ 1-1052-AP ┆           ┆          │
# │ tasa cred ┆ S.A.      ┆           ┆ cepas ext ┆   ┆           ┆ N-SIECYGC ┆           ┆          │
# │ itici…    ┆           ┆           ┆ ra-regi…  ┆   ┆           ┆ E#M…      ┆           ┆          │
# │ ANR       ┆ Servicio  ┆ 306883845 ┆ Desarroll ┆ … ┆ 200001000 ┆ RESOL-202 ┆ 9165481   ┆ null     │
# │           ┆ Nacional  ┆ 47        ┆ o de      ┆   ┆ 0         ┆ 1-1052-AP ┆           ┆          │
# │           ┆ De        ┆           ┆ cepas ext ┆   ┆           ┆ N-SIECYGC ┆           ┆          │
# │           ┆ Sanidad   ┆           ┆ ra-regi…  ┆   ┆           ┆ E#M…      ┆           ┆          │
# │           ┆ Y…        ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ANR       ┆ Ferretera ┆ 307072971 ┆ Relevamie ┆ … ┆ 141402200 ┆ RESOL-202 ┆ 860000    ┆ null     │
# │           ┆ General   ┆ 54        ┆ nto de    ┆   ┆ 00        ┆ 2-160-APN ┆           ┆          │
# │           ┆ Paz       ┆           ┆ depósitos ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆ S.R.L.    ┆           ┆ a tr…     ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ Bonificac ┆ Ferretera ┆ 307072971 ┆ Relevamie ┆ … ┆ 141402200 ┆ RESOL-202 ┆ null      ┆ 196123   │
# │ ión de    ┆ General   ┆ 54        ┆ nto de    ┆   ┆ 00        ┆ 2-160-APN ┆           ┆          │
# │ tasa cred ┆ Paz       ┆           ┆ depósitos ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆ S.R.L.    ┆           ┆ a tr…     ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Fundación ┆ 307101811 ┆ Relevamie ┆ … ┆ 140140100 ┆ RESOL-202 ┆ 4950000   ┆ null     │
# │           ┆ Emprendim ┆ 75        ┆ nto de    ┆   ┆ 00        ┆ 2-160-APN ┆           ┆          │
# │           ┆ ientos Y  ┆           ┆ depósitos ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆ De…       ┆           ┆ a tr…     ┆   ┆           ┆ #MD…      ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘>

# %%
62 * 14 ### filas por columnas
# Out:
# 868

# %% [markdown]
# <p align="justify"> 👀 Para leer un archivo en partes, se utiliza el parametro <code>chunksize</code> y se especifica el número de filas o índices.
# </p>

# %%
datos
# Out:
# 'https://raw.githubusercontent.com/cristiandarioortegayubro/BDS/main/datasets/beneficios-otorgados-colaborativa-202210.xlsx-Dataset.csv'

# %%
partes = pd.read_csv(datos, chunksize=20)

# %% [markdown]
# <p align="justify">
# El script <code>partes = pd.read_csv(datos, chunksize=20)</code> utiliza la función <code>read_csv</code> de la biblioteca pandas para leer un archivo CSV en partes o "chunks" de 20 filas cada una, en lugar de cargar el archivo completo en memoria. Esto es útil para manejar archivos grandes de manera más eficiente, permitiendo procesar los datos en fragmentos más pequeños y reducir el consumo de memoria.
# <br><br>
# La variable <code>partes</code> contendrá un iterador sobre estos fragmentos de datos.

# %%
type(partes)
# Out:
# pandas.io.parsers.readers.TextFileReader

# %%
beneficios = pd.Series([], dtype="int64")

# %%
beneficios  ### serie vacia
# Out:
# Series([], dtype: int64)

# %%
for i in partes:
    beneficios = beneficios.add(i["beneficio_tipo"].value_counts(), fill_value=0)

# %% [markdown]
# <p align="justify">
# El script itera sobre cada fragmento de datos generado por un iterador de pandas y actualiza la serie <code>beneficios</code> sumando los conteos de valores únicos de la columna <code>"beneficio_tipo"</code> de cada fragmento. El método <code>add</code> combina los conteos acumulados de cada fragmento, utilizando <code>fill_value=0</code> para manejar valores faltantes y asegurarse de que se sumen correctamente incluso si algunos fragmentos tienen categorías diferentes.
# <br><br>
# Esto permite consolidar los conteos de beneficio a lo largo de todo el conjunto de datos dividido en fragmentos.

# %%
beneficios  ###
# Out:
# beneficio_tipo
# ANR                                39.0
# Bonificación de tasa crediticia    23.0
# dtype: float64

# %%
beneficios = beneficios.sort_values(ascending=False)
beneficios
# Out:
# beneficio_tipo
# ANR                                39.0
# Bonificación de tasa crediticia    23.0
# dtype: float64

# %% [markdown]
# <p align="justify"> 👀 En el caso de la funcion <code>read_csv()</code>, los parámetros más destacados, son los siguientes:
# <ul>
# <li><code>path()</code> indica la ubicación del sistema de archivos, URL u objeto similar a un archivo</li>
# <li><code>sep()</code> caracteres o expresión regular que se usará para dividir campos en cada fila</li>
# <li><code>header()</code> número de fila para nombres de columna, debería ser <code>None</code> si no hay encabezado.</li>
# <li><code>index_col()</code> número de columna o nombre de columna para usar como índice</li>
# <li><code>names()</code> lista de nombres de columnas</li>
# <li><code>skiprows()</code> número de filas al principio del archivo para ignorar o lista de números de fila (a partir de 0) para omitir</li>
# <li><code>na_values()</code> secuencia de valores para reemplazar con NA</li>
# <li><code>keep_default_na()</code> usar o no la lista de valores predeterminados NA (<code>True</code> por defecto)</li>
# <li><code>parse_dates()</code> intenta analizar los datos en <code>datetime</code></li>
# <li><code>converters()</code> aplicaría la función <code>f</code> a los valores indicados </li>
# <li><code>dayfirst()</code> al analizar fechas ambiguas, se le aplica formato internacional</li>
# <li><code>verbose()</code> muestra información de análisis diversa</li>
# <li><code>encoding()</code> codificación de texto</li>
# <li><code>squeeze()</code> Si los datos analizados contienen solo una columna, devuelva una <code>Serie</code></li>
# <li><code>thousands()</code> separador de miles</li>
# <li><code>decimal()</code> separador decimal</li>
# <li><code>engine()</code> motor de conversión y análisis de CSV para usar</li>
# </ul>
# </p>

# %% [markdown]
#  ## **<font color="#07a8ed">Escritura de archivos</font>**

# %% [markdown]
# <p align="justify">
# Los datos también se pueden exportar a un formato delimitado.</p>

# %%
subsidios
# Out:
# shape: (62, 14)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ beneficio ┆ beneficia ┆ beneficia ┆ proyecto_ ┆ … ┆ localidad ┆ resolucio ┆ anr_abona ┆ subsidio │
# │ _tipo     ┆ rio_razon ┆ rio_cuit  ┆ nombre    ┆   ┆ _id       ┆ n         ┆ do        ┆ _tasa_cr │
# │ ---       ┆ _social   ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ edito    │
# │ str       ┆ ---       ┆ i64       ┆ str       ┆   ┆ i64       ┆ str       ┆ i64       ┆ ---      │
# │           ┆ str       ┆           ┆           ┆   ┆           ┆           ┆           ┆ str      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ Bonificac ┆ Esg Dilec ┆ 307083345 ┆ Sistema   ┆ … ┆ 820842700 ┆ RESOL-202 ┆ null      ┆ 4008128  │
# │ ión de    ┆ SA        ┆ 84        ┆ multiplat ┆   ┆ 00        ┆ 1-407-APN ┆           ┆          │
# │ tasa cred ┆           ┆           ┆ aforma de ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆           ┆           ┆ lec…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Esg Dilec ┆ 307083345 ┆ Sistema   ┆ … ┆ 820842700 ┆ RESOL-202 ┆ 4954725   ┆ null     │
# │           ┆ SA        ┆ 84        ┆ multiplat ┆   ┆ 00        ┆ 1-407-APN ┆           ┆          │
# │           ┆           ┆           ┆ aforma de ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆           ┆           ┆ lec…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Laborator ┆ 306380641 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ 4482165   ┆ null     │
# │           ┆ io        ┆ 26        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │           ┆ Biológico ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆ Tandil S… ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ Bonificac ┆ Laborator ┆ 306380641 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ null      ┆ 720530   │
# │ ión de    ┆ io        ┆ 26        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │ tasa cred ┆ Biológico ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆ Tandil S… ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ Bonificac ┆ Redimec   ┆ 336297839 ┆ Fabricaci ┆ … ┆ 679105000 ┆ RESOL-202 ┆ null      ┆ 737628   │
# │ ión de    ┆ SRL       ┆ 09        ┆ ón de Pol ┆   ┆ 0         ┆ 1-416-APN ┆           ┆          │
# │ tasa cred ┆           ┆           ┆ arímetro  ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆           ┆           ┆ nac…      ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ Bonificac ┆ Biogénesi ┆ 306533998 ┆ Desarroll ┆ … ┆ 625201000 ┆ RESOL-202 ┆ null      ┆ 7137021  │
# │ ión de    ┆ s Bagó    ┆ 19        ┆ o de      ┆   ┆ 3         ┆ 1-1052-AP ┆           ┆          │
# │ tasa cred ┆ S.A.      ┆           ┆ cepas ext ┆   ┆           ┆ N-SIECYGC ┆           ┆          │
# │ itici…    ┆           ┆           ┆ ra-regi…  ┆   ┆           ┆ E#M…      ┆           ┆          │
# │ ANR       ┆ Servicio  ┆ 306883845 ┆ Desarroll ┆ … ┆ 200001000 ┆ RESOL-202 ┆ 9165481   ┆ null     │
# │           ┆ Nacional  ┆ 47        ┆ o de      ┆   ┆ 0         ┆ 1-1052-AP ┆           ┆          │
# │           ┆ De        ┆           ┆ cepas ext ┆   ┆           ┆ N-SIECYGC ┆           ┆          │
# │           ┆ Sanidad   ┆           ┆ ra-regi…  ┆   ┆           ┆ E#M…      ┆           ┆          │
# │           ┆ Y…        ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# │ ANR       ┆ Ferretera ┆ 307072971 ┆ Relevamie ┆ … ┆ 141402200 ┆ RESOL-202 ┆ 860000    ┆ null     │
# │           ┆ General   ┆ 54        ┆ nto de    ┆   ┆ 00        ┆ 2-160-APN ┆           ┆          │
# │           ┆ Paz       ┆           ┆ depósitos ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆ S.R.L.    ┆           ┆ a tr…     ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ Bonificac ┆ Ferretera ┆ 307072971 ┆ Relevamie ┆ … ┆ 141402200 ┆ RESOL-202 ┆ null      ┆ 196123   │
# │ ión de    ┆ General   ┆ 54        ┆ nto de    ┆   ┆ 00        ┆ 2-160-APN ┆           ┆          │
# │ tasa cred ┆ Paz       ┆           ┆ depósitos ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │ itici…    ┆ S.R.L.    ┆           ┆ a tr…     ┆   ┆           ┆ #MD…      ┆           ┆          │
# │ ANR       ┆ Fundación ┆ 307101811 ┆ Relevamie ┆ … ┆ 140140100 ┆ RESOL-202 ┆ 4950000   ┆ null     │
# │           ┆ Emprendim ┆ 75        ┆ nto de    ┆   ┆ 00        ┆ 2-160-APN ┆           ┆          │
# │           ┆ ientos Y  ┆           ┆ depósitos ┆   ┆           ┆ -SIECYGCE ┆           ┆          │
# │           ┆ De…       ┆           ┆ a tr…     ┆   ┆           ┆ #MD…      ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
subsidios2 = subsidios.filter[0:10,[0,2]]
subsidios2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-55bec2ac6610> in <cell line: 1>()
# ----> 1 subsidios2 = subsidios.filter[0:10,[0,2]]
#       2 subsidios2
#
# TypeError: 'method' object is not subscriptable

# %%
subsidios2.shape
# Out:
# (10, 2)

# %% [markdown]
# <p align="justify"> 👀 Usando el método <code>to_csv()</code>, podemos escribir los datos en un archivo separado por comas.
# </p>

# %%
subsidios2.to_csv("subsidios.csv") # para grabar a un archivo csv

# %%
subsidios2.to_csv("subsidios.csv")
# !cat subsidios.csv # para poder visualizar el archivo en la celda
# Out:
# ,beneficio_tipo,beneficiario_cuit
# 0,Bonificación de tasa crediticia,30708334584
# 1,ANR,30708334584
# 2,ANR,30638064126
# 3,Bonificación de tasa crediticia,30638064126
# 4,Bonificación de tasa crediticia,33629783909
# 5,ANR,33629783909
# 6,ANR,30709392243
# 7,Bonificación de tasa crediticia,30709585939
# 8,ANR,30709585939
# 9,ANR,30560312411

# %% [markdown]
# <p align="justify">
# El script guarda el DataFrame <code>subsidios2</code> en un archivo CSV llamado "subsidios.csv". Luego, el comando <code>!cat subsidios.csv</code> se utiliza para mostrar el contenido del archivo "subsidios.csv" directamente en la celda, permitiendo verificar el contenido del archivo creado.

# %% [markdown]
# <p align="justify"> 👀 Se puede usar otros delimitadores.
# </p>

# %%
subsidios2.to_csv("subsidios.csv", sep=";")
# !cat subsidios.csv
# Out:
# ;beneficio_tipo;beneficiario_cuit
# 0;Bonificación de tasa crediticia;30708334584
# 1;ANR;30708334584
# 2;ANR;30638064126
# 3;Bonificación de tasa crediticia;30638064126
# 4;Bonificación de tasa crediticia;33629783909
# 5;ANR;33629783909
# 6;ANR;30709392243
# 7;Bonificación de tasa crediticia;30709585939
# 8;ANR;30709585939
# 9;ANR;30560312411

# %%
subsidios2.to_csv("subsidios.csv", sep="|")
# !cat subsidios.csv
# Out:
# |beneficio_tipo|beneficiario_cuit
# 0|Bonificación de tasa crediticia|30708334584
# 1|ANR|30708334584
# 2|ANR|30638064126
# 3|Bonificación de tasa crediticia|30638064126
# 4|Bonificación de tasa crediticia|33629783909
# 5|ANR|33629783909
# 6|ANR|30709392243
# 7|Bonificación de tasa crediticia|30709585939
# 8|ANR|30709585939
# 9|ANR|30560312411

# %%
df2 = pd.read_csv("/content/subsidios.csv", sep="|")
df2
# Out:
#    Unnamed: 0                   beneficio_tipo  beneficiario_cuit
# 0           0  Bonificación de tasa crediticia        30708334584
# 1           1                              ANR        30708334584
# 2           2                              ANR        30638064126
# 3           3  Bonificación de tasa crediticia        30638064126
# 4           4  Bonificación de tasa crediticia        33629783909
# 5           5                              ANR        33629783909
# 6           6                              ANR        30709392243
# 7           7  Bonificación de tasa crediticia        30709585939
# 8           8                              ANR        30709585939
# 9           9                              ANR        30560312411

# %% [markdown]
# <p align="justify"> 👀 Se puede prescindir del índice.
# </p>

# %%
subsidios2.to_csv("subsidios.csv", index=False)
# !cat subsidios.csv
# Out:
# beneficio_tipo,beneficiario_cuit
# Bonificación de tasa crediticia,30708334584
# ANR,30708334584
# ANR,30638064126
# Bonificación de tasa crediticia,30638064126
# Bonificación de tasa crediticia,33629783909
# ANR,33629783909
# ANR,30709392243
# Bonificación de tasa crediticia,30709585939
# ANR,30709585939
# ANR,30560312411

# %%
df2 = pd.read_csv("/content/subsidios.csv")
df2
# Out:
#                     beneficio_tipo  beneficiario_cuit
# 0  Bonificación de tasa crediticia        30708334584
# 1                              ANR        30708334584
# 2                              ANR        30638064126
# 3  Bonificación de tasa crediticia        30638064126
# 4  Bonificación de tasa crediticia        33629783909
# 5                              ANR        33629783909
# 6                              ANR        30709392243
# 7  Bonificación de tasa crediticia        30709585939
# 8                              ANR        30709585939
# 9                              ANR        30560312411

# %% [markdown]
# <p align="justify"> 👀 y tambien, entre otras cosas, se puede prescindir del encabezado.
# </p>

# %%
subsidios2.to_csv("subsidios.csv", index=False, header=True) # con encabezados
# !cat subsidios.csv
# Out:
# beneficio_tipo,beneficiario_cuit
# Bonificación de tasa crediticia,30708334584
# ANR,30708334584
# ANR,30638064126
# Bonificación de tasa crediticia,30638064126
# Bonificación de tasa crediticia,33629783909
# ANR,33629783909
# ANR,30709392243
# Bonificación de tasa crediticia,30709585939
# ANR,30709585939
# ANR,30560312411

# %%
df2 = pd.read_csv("/content/subsidios.csv")
df2
# Out:
#                     beneficio_tipo  beneficiario_cuit
# 0  Bonificación de tasa crediticia        30708334584
# 1                              ANR        30708334584
# 2                              ANR        30638064126
# 3  Bonificación de tasa crediticia        30638064126
# 4  Bonificación de tasa crediticia        33629783909
# 5                              ANR        33629783909
# 6                              ANR        30709392243
# 7  Bonificación de tasa crediticia        30709585939
# 8                              ANR        30709585939
# 9                              ANR        30560312411

# %%
subsidios2.to_csv("subsidios.csv", index=False, header=False) # sin encabezados
# !cat subsidios.csv
# Out:
# Bonificación de tasa crediticia,30708334584
# ANR,30708334584
# ANR,30638064126
# Bonificación de tasa crediticia,30638064126
# Bonificación de tasa crediticia,33629783909
# ANR,33629783909
# ANR,30709392243
# Bonificación de tasa crediticia,30709585939
# ANR,30709585939
# ANR,30560312411

# %%
df2 = pd.read_csv("/content/subsidios.csv")
df2
# Out:
#    Bonificación de tasa crediticia  30708334584
# 0                              ANR  30708334584
# 1                              ANR  30638064126
# 2  Bonificación de tasa crediticia  30638064126
# 3  Bonificación de tasa crediticia  33629783909
# 4                              ANR  33629783909
# 5                              ANR  30709392243
# 6  Bonificación de tasa crediticia  30709585939
# 7                              ANR  30709585939
# 8                              ANR  30560312411

# %% [markdown]
#  # **<font color="#07a8ed">HTML Web Scraping</font>**

# %% [markdown]
# <p align="justify">
# <code>Python</code> tiene muchas bibliotecas para leer y escribir datos en los  formatos <code>HTML</code> y <code>XML</code>. Los ejemplos incluyen <code>lxml</code>, <code>Beautiful Soup</code> y <code>html5lib</code>. Si bien <code>lxml</code> es comparativamente mucho más rápido en general, las otras bibliotecas pueden manejar mejor los archivos <code>HTML</code> o <code>XML</code> con formato incorrecto.</p>

# %% [markdown]
# <p align="justify"> 👀 <code>Pandas</code> tiene una función integrada, <code>read_html</code> que utiliza todas estas bibliotecas para analizar automáticamente las tablas de los archivos <code>HTML</code> como objetos <code>DataFrame</code>.
# </p>

# %% [markdown]
# <p align="justify"> 👀 Es recomendable habilitar algunas bibliotecas adicionales, en este caso, las que usa la función <code>read_html</code>.
# </p>

# %%
# import lxml
# import bs4
# import html5lib

# %%
URL = "https://atm.mendoza.gov.ar/portalatm/zoneBottom/datosInteres/recaudacion/recaudacion_impuesto_ingresos.jsp"

# %%
recaudacion = pd.read_html(URL, encoding='iso-8859-1')

# %% [markdown]
# <p align="justify"> 👀 El resultado de usar la función <code>read_html</code> es una lista de objetos <code>DataFrame</code>.
# </p>

# %%
type(recaudacion)
# Out:
# list

# %%
len(recaudacion)
# Out:
# 1

# %%
df = recaudacion[0]
df
# Out:
#                 0                1                2                3    \
# 0   Ingresos Brutos  Ingresos Brutos  Ingresos Brutos  Ingresos Brutos
# 1             Meses             2000             2001             2002
# 2             Enero         18843926         18114420         12722708
# 3           Febrero         16258743         32180909         11237981
# 4             Marzo         17468327         14453688         11460186
# 5             Abril         17463084         15809614         12300935
# 6              Mayo         15978692         14610889         14265621
# 7             Junio         14676011         14328045         16351168
# 8             Julio         15299790         14675150         17106546
# 9            Agosto         15802483         14475158         18373950
# 10       Septiembre         15756538         16781292         18684199
# 11          Octubre         15731005         13506128         18518490
# 12        Noviembre         15660556         13446877         21317298
# 13        Diciembre         16032799         11570299         19508401
# 14          Totales        194971954        193952469        191847483
#
#                 4                5                6                7    \
# 0   Ingresos Brutos  Ingresos Brutos  Ingresos Brutos  Ingresos Brutos
# 1              2003             2004             2005             2006
# 2          20192886         28492948         37455922         48307581
# 3          20257924         26276427         35131740         45290618
# 4          19766456         27124258         33982257         45654235
# 5          20503786         32466739         39149216         47268950
# 6          20988947         30252979         39887132         60082271
# 7          21041197         30687746         39160678         56268381
# 8          21763328         30962034         39205417         59484119
# 9          23185411         31937418         40688413         58732118
# 10         25513569         31578993         43003892         63159166
# 11         25042384         33774686         41477902         63007199
# 12         25520492         33742035         42190330         61376701
# 13         25122948         34519525         45989899         55169335
# 14        268899328        371815788        477322798        663800674
#
#                 8                9    ...              241              242  \
# 0   Ingresos Brutos  Ingresos Brutos  ...  Ingresos Brutos  Ingresos Brutos
# 1              2007             2008  ...              NaN              NaN
# 2          61131913         88818881  ...              NaN              NaN
# 3          58230197         76675888  ...              NaN              NaN
# 4          58267059         74072263  ...              NaN              NaN
# 5          61113108         88241185  ...              NaN              NaN
# 6          65113469         90479860  ...              NaN              NaN
# 7          65906755         83292810  ...              NaN              NaN
# 8          66270873         88028892  ...              NaN              NaN
# 9          67496826         94763397  ...              NaN              NaN
# 10         70058014         91342609  ...              NaN              NaN
# 11         72036143         90090534  ...              NaN              NaN
# 12         75454989         85291059  ...              NaN              NaN
# 13         66286135         88008564  ...              NaN              NaN
# 14        787365481       1039105942  ...              NaN              NaN
#
#                 243              244              245              246  \
# 0   Ingresos Brutos  Ingresos Brutos  Ingresos Brutos  Ingresos Brutos
# 1               NaN              NaN              NaN              NaN
# 2               NaN              NaN              NaN              NaN
# 3               NaN              NaN              NaN              NaN
# 4               NaN              NaN              NaN              NaN
# 5               NaN              NaN              NaN              NaN
# 6               NaN              NaN              NaN              NaN
# 7               NaN              NaN              NaN              NaN
# 8               NaN              NaN              NaN              NaN
# 9               NaN              NaN              NaN              NaN
# 10              NaN              NaN              NaN              NaN
# 11              NaN              NaN              NaN              NaN
# 12              NaN              NaN              NaN              NaN
# 13              NaN              NaN              NaN              NaN
# 14              NaN              NaN              NaN              NaN
#
#                 247              248              249              250
# 0   Ingresos Brutos  Ingresos Brutos  Ingresos Brutos  Ingresos Brutos
# 1               NaN              NaN              NaN              NaN
# 2               NaN              NaN              NaN              NaN
# 3               NaN              NaN              NaN              NaN
# 4               NaN              NaN              NaN              NaN
# 5               NaN              NaN              NaN              NaN
# 6               NaN              NaN              NaN              NaN
# 7               NaN              NaN              NaN              NaN
# 8               NaN              NaN              NaN              NaN
# 9               NaN              NaN              NaN              NaN
# 10              NaN              NaN              NaN              NaN
# 11              NaN              NaN              NaN              NaN
# 12              NaN              NaN              NaN              NaN
# 13              NaN              NaN              NaN              NaN
# 14              NaN              NaN              NaN              NaN
#
# [15 rows x 251 columns]

# %% [markdown]
# <p align="justify">Este es un <code>DataFrame</code> ideal para hacer tareas de limpieza y transformación de datos.
# </p>

# %%
df.loc[:,0:25]
# Out:
#                  0                1                2                3   \
# 0   Ingresos Brutos  Ingresos Brutos  Ingresos Brutos  Ingresos Brutos
# 1             Meses             2000             2001             2002
# 2             Enero         18843926         18114420         12722708
# 3           Febrero         16258743         32180909         11237981
# 4             Marzo         17468327         14453688         11460186
# 5             Abril         17463084         15809614         12300935
# 6              Mayo         15978692         14610889         14265621
# 7             Junio         14676011         14328045         16351168
# 8             Julio         15299790         14675150         17106546
# 9            Agosto         15802483         14475158         18373950
# 10       Septiembre         15756538         16781292         18684199
# 11          Octubre         15731005         13506128         18518490
# 12        Noviembre         15660556         13446877         21317298
# 13        Diciembre         16032799         11570299         19508401
# 14          Totales        194971954        193952469        191847483
#
#                  4                5                6                7   \
# 0   Ingresos Brutos  Ingresos Brutos  Ingresos Brutos  Ingresos Brutos
# 1              2003             2004             2005             2006
# 2          20192886         28492948         37455922         48307581
# 3          20257924         26276427         35131740         45290618
# 4          19766456         27124258         33982257         45654235
# 5          20503786         32466739         39149216         47268950
# 6          20988947         30252979         39887132         60082271
# 7          21041197         30687746         39160678         56268381
# 8          21763328         30962034         39205417         59484119
# 9          23185411         31937418         40688413         58732118
# 10         25513569         31578993         43003892         63159166
# 11         25042384         33774686         41477902         63007199
# 12         25520492         33742035         42190330         61376701
# 13         25122948         34519525         45989899         55169335
# 14        268899328        371815788        477322798        663800674
#
#                  8                9   ...               16               17  \
# 0   Ingresos Brutos  Ingresos Brutos  ...  Ingresos Brutos  Ingresos Brutos
# 1              2007             2008  ...             2015             2016
# 2          61131913         88818881  ...        782112955        990329978
# 3          58230197         76675888  ...        729820564        919810308
# 4          58267059         74072263  ...        702603251        965441676
# 5          61113108         88241185  ...        741563435       1046270167
# 6          65113469         90479860  ...        770937471       1043528821
# 7          65906755         83292810  ...        774531242        991656616
# 8          66270873         88028892  ...        856524734       1105998076
# 9          67496826         94763397  ...        859765325       1127364425
# 10         70058014         91342609  ...        831099102       1141604417
# 11         72036143         90090534  ...        897798301       1098256448
# 12         75454989         85291059  ...        896822309       1175329181
# 13         66286135         88008564  ...        928323895       1192269519
# 14        787365481       1039105942  ...       9771902584      12797859632
#
#                  18               19               20               21  \
# 0   Ingresos Brutos  Ingresos Brutos  Ingresos Brutos  Ingresos Brutos
# 1              2017             2018             2019             2020
# 2        1317982229       1642808124       2195529730       3068476937
# 3        1194014665       1497939109       2103363732       3246583141
# 4        1202600310       1492442509       2143791335       2869934807
# 5        1386964121       1611327512       2277286791       2711722096
# 6        1288922134       1630360944       2456053054       2558796240
# 7        1291359719       1725684002       2334065968       2601499359
# 8        1355228857       1734466058       2419755126       2800037597
# 9        1460045961       1884253360       2761171810       3271900805
# 10       1518901732       2059133833       2874249708       3102345313
# 11       1483261492       2154164859       2863717767       3254208843
# 12       1484020632       2203835394       2963817482       3590381705
# 13       1668256848       2105064934       2857067481       3619140640
# 14      16651558700      21741480638      30249869984      36695027483
#
#                  22               23               24               25
# 0   Ingresos Brutos  Ingresos Brutos  Ingresos Brutos  Ingresos Brutos
# 1              2021             2022             2023             2024
# 2        4210333243       6815275641      14525560710      47346036894
# 3        4035920128       6525087915      14960067498      52411425612
# 4        3969197922       6633613415      15059684558      56751086613
# 5        4446800638     7882943560.5      17487400044      60502130948
# 6        4285918498       8485148694      18906730844      64921410660
# 7        4477259473       8272230858      20011320650      66006863236
# 8        4653112414       9777144943      22575360462      66390437802
# 9        4977782152      10673847335      24771434365              NaN
# 10       5349090672      10903034059      28058793576              NaN
# 11       5368896164      11468663772      33556861396              NaN
# 12       5800018664      12420675590      35453717484              NaN
# 13       6548178069      12973069983      36875546852              NaN
# 14      58122508037   112830735765.5     282242478439     414329391765
#
# [15 rows x 26 columns]

# %% [markdown]
#  # **<font color="#07a8ed">Algunos formatos de datos binarios</font>**

# %% [markdown]
# <p align="justify">
# Una forma sencilla de almacenar o serializar datos en formato binario es usar el módulo integrado de <code>Python</code> denominado <code>pickle</code>. Todos los objetos <code>Pandas</code> tienen un metodo <code>to_pickle()</code> que escribe los datos en formato <code>pickle</code>.</p>

# %%
subsidios2
# Out:
#                     beneficio_tipo  beneficiario_cuit
# 0  Bonificación de tasa crediticia        30708334584
# 1                              ANR        30708334584
# 2                              ANR        30638064126
# 3  Bonificación de tasa crediticia        30638064126
# 4  Bonificación de tasa crediticia        33629783909
# 5                              ANR        33629783909
# 6                              ANR        30709392243
# 7  Bonificación de tasa crediticia        30709585939
# 8                              ANR        30709585939
# 9                              ANR        30560312411

# %% [markdown]
#  ## **<font color="#07a8ed">Pickle</font>**

# %%
subsidios2.to_pickle("subsidios.pkl")

# %%
df_pickle = pd.read_pickle("subsidios.pkl")
df_pickle
# Out:
#                     beneficio_tipo  beneficiario_cuit
# 0  Bonificación de tasa crediticia        30708334584
# 1                              ANR        30708334584
# 2                              ANR        30638064126
# 3  Bonificación de tasa crediticia        30638064126
# 4  Bonificación de tasa crediticia        33629783909
# 5                              ANR        33629783909
# 6                              ANR        30709392243
# 7  Bonificación de tasa crediticia        30709585939
# 8                              ANR        30709585939
# 9                              ANR        30560312411

# %% [markdown]
#  ## **<font color="#07a8ed">Parquet</font>**

# %%
subsidios2.to_parquet("subsidios.parquet")

# %%
df_parquet = pd.read_parquet("subsidios.parquet")
df_parquet
# Out:
#                     beneficio_tipo  beneficiario_cuit
# 0  Bonificación de tasa crediticia        30708334584
# 1                              ANR        30708334584
# 2                              ANR        30638064126
# 3  Bonificación de tasa crediticia        30638064126
# 4  Bonificación de tasa crediticia        33629783909
# 5                              ANR        33629783909
# 6                              ANR        30709392243
# 7  Bonificación de tasa crediticia        30709585939
# 8                              ANR        30709585939
# 9                              ANR        30560312411

# %% [markdown]
#  # **<font color="#07a8ed">Otros formatos</font>**

# %% [markdown]
#  ## **<font color="#07a8ed">Json</font>**

# %%
subsidios2.to_json("subsidios.json")

# %%
df_json = pd.read_json("subsidios.json")
df_json
# Out:
#                     beneficio_tipo  beneficiario_cuit
# 0  Bonificación de tasa crediticia        30708334584
# 1                              ANR        30708334584
# 2                              ANR        30638064126
# 3  Bonificación de tasa crediticia        30638064126
# 4  Bonificación de tasa crediticia        33629783909
# 5                              ANR        33629783909
# 6                              ANR        30709392243
# 7  Bonificación de tasa crediticia        30709585939
# 8                              ANR        30709585939
# 9                              ANR        30560312411

# %% [markdown]
#  ## **<font color="#07a8ed">Hdf</font>**

# %%
subsidios2.to_hdf("subsidios.h5", key="df")

# %%
df_hdf = pd.read_hdf("subsidios.h5", key="df")
df_hdf
# Out:
#                     beneficio_tipo  beneficiario_cuit
# 0  Bonificación de tasa crediticia        30708334584
# 1                              ANR        30708334584
# 2                              ANR        30638064126
# 3  Bonificación de tasa crediticia        30638064126
# 4  Bonificación de tasa crediticia        33629783909
# 5                              ANR        33629783909
# 6                              ANR        30709392243
# 7  Bonificación de tasa crediticia        30709585939
# 8                              ANR        30709585939
# 9                              ANR        30560312411

# %% [markdown]
# <br>
# <br>
# <p align="center"><b>
# 💗
# <font color="#07a8ed">
# Hemos llegado al final de nuestro colab de Pandas, a seguir codeando...
# </font>
# </p>
